# %%
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('D:/Photos/Random/wallpaperflare.com_wallpaper (17).jpg')
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# ## Find RED, Green, Blue plane of the color image

# %%
b,g,r = cv2.split(img)
plt.imshow(g)

# %%
img = cv2.imread('D:/Photos/Random/wallpaperflare.com_wallpaper (17).jpg',0)
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.show()

# %%
print(img.shape)
# Out:
# (1080, 1920)

# %%
resize_img_half=cv2.resize(img,(256,256))
print(resize_img_half.shape)
# Out:
# (256, 256)

# %%
resize_img_quarter = cv2.resize(img,(128,128))
print(resize_img_quarter.shape)
# Out:
# (128, 128)

# %%
resize_img_half=cv2.resize(img,(256,256))
print(resize_img_half.shape)
plt.imshow(cv2.cvtColor(resize_img_half, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# (256, 256)

# %%
resize_img_half=cv2.resize(img,(128,128))
print(resize_img_half.shape)
plt.imshow(cv2.cvtColor(resize_img_quarter, cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# (128, 128)

# %%
# Check if the image is grayscale
if len(img.shape) < 3:
    # Convert grayscale image to color image
    img = cv2.cvtColor(img, cv2.COLOR_GRAY2BGR)

# Split the image into channels
b, g, r = cv2.split(img)
plt.imshow(r)

# %%
plt.subplot(1,3,1)
plt.imshow(cv2.cvtColor(b, cv2.COLOR_BGR2RGB))
plt.show()

# %%
plt.subplot(1,3,2)
plt.imshow(cv2.cvtColor(r, cv2.COLOR_BGR2RGB))
plt.show()

# %%
plt.subplot(1,3,3)
plt.imshow(cv2.cvtColor(g, cv2.COLOR_BGR2RGB))
plt.show()

# %%
b,g,r = cv2.split(img)
plt.subplot(1,3,1)
plt.imshow(cv2.cvtColor(b, cv2.COLOR_BGR2RGB))
plt.subplot(1,3,2)
plt.imshow(cv2.cvtColor(r, cv2.COLOR_BGR2RGB))
plt.subplot(1,3,3)
plt.imshow(cv2.cvtColor(g, cv2.COLOR_BGR2RGB))
plt.show()

# %%
image90=cv2.rotate(img,cv2.ROTATE_90_CLOCKWISE)
plt.imshow(cv2.cvtColor(image90,cv2.COLOR_BGR2RGB))
plt.show()
image180=cv2.rotate(img,cv2.ROTATE_180)
plt.imshow(cv2.cvtColor(image180,cv2.COLOR_BGR2RGB))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 7
#       5 plt.imshow(cv2.cvtColor(image180,cv2.COLOR_BGR2RGB))
#       6 plt.show()
# ----> 7 image45 = cv2.rotate(img, cv2.ROTATE_45_CLOCKWISE)
#       8 plt.imshow(cv2.cvtColor(image45, cv2.COLOR_BGR2RGB))
#       9 plt.show()
#
# AttributeError: module 'cv2' has no attribute 'ROTATE_45_CLOCKWISE'

# %%
# Define a function to rotate the image
def rotate_image(image, angle):
    (h, w) = image.shape[:2]
    center = (w // 2, h // 2)

    # Rotate the image
    M = cv2.getRotationMatrix2D(center, angle, 1.0)
    rotated = cv2.warpAffine(image, M, (w, h))
    return rotated

# Rotate images by 45, 90, and 180 degrees
img_45 = rotate_image(img, 45)
img_90 = rotate_image(img, 90)
img_180 = rotate_image(img, 180)

# Display the images
plt.figure(figsize=(10, 8))

plt.subplot(1, 3, 1)
plt.imshow(cv2.cvtColor(img_45, cv2.COLOR_BGR2RGB))
plt.title("45 Degrees")

plt.subplot(1, 3, 2)
plt.imshow(cv2.cvtColor(img_90, cv2.COLOR_BGR2RGB))
plt.title("90 Degrees")

plt.subplot(1, 3, 3)
plt.imshow(cv2.cvtColor(img_180, cv2.COLOR_BGR2RGB))
plt.title("180 Degrees")

plt.show()
